# %% [markdown]
# <a href="https://colab.research.google.com/github/ShawnDhillon1/167-DL/blob/main/8.3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-il_mj3_b
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-il_mj3_b
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=198a1ef04930791064c97e2d4eace24cc44a52e4c037c2562c6346bb17ed8187
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eeurqcc0/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# 1. at 0
# 2. around 1700
# 3. around 3800

# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301906, train error 89.93,  test loss 2.301978, test error 89.75
# Epoch   100, train loss 1.928518, train error 73.22,  test loss 1.783101, test error 70.45
# Epoch   200, train loss 1.911298, train error 72.45,  test loss 1.755052, test error 68.88
# Epoch   300, train loss 1.905520, train error 71.72,  test loss 1.747572, test error 69.68
# Epoch   400, train loss 1.904058, train error 71.80,  test loss 1.739659, test error 70.07
# Epoch   500, train loss 1.902737, train error 70.93,  test loss 1.735133, test error 69.47
# Epoch   600, train loss 1.900865, train error 70.75,  test loss 1.742516, test error 69.43
# Epoch   700, train loss 1.901724, train error 70.68,  test loss 1.745839, test error 68.62
# Epoch   800, train loss 1.901371, train error 70.93,  test loss 1.741428, test error 69.85
# Epoch   900, train loss 1.904124, train error 71.43,  test loss 1.756728, test error 69.68
# Training model with   4 hidden variables
# Epoch     0, train loss 2.304094, train error 88.57,  test loss 2.305659, test error 89.45
# Epoch   100, train loss 1.914107, train error 71.28,  test loss 1.776748, test error 68.40
# Epoch   200, train loss 1.894499, train error 70.50,  test loss 1.743891, test error 69.43
# Epoch   300, train loss 1.890262, train error 71.15,  test loss 1.742682, test error 69.25
# Epoch   400, train loss 1.884760, train error 70.85,  test loss 1.733518, test error 69.85
# Epoch   500, train loss 1.882167, train error 71.10,  test loss 1.732988, test error 69.22
# Epoch   600, train loss 1.884216, train error 71.03,  test loss 1.730212, test error 68.43
# Epoch   700, train loss 1.880783, train error 71.07,  test loss 1.729038, test error 68.68
# Epoch   800, train loss 1.874529, train error 69.88,  test loss 1.735035, test error 69.03
# Epoch   900, train loss 1.877467, train error 69.55,  test loss 1.739018, test error 69.50
# Training model with   6 hidden variables
# Epoch     0, train loss 2.303683, train error 85.88,  test loss 2.313404, test error 86.03
# Epoch   100, train loss 1.728022, train error 62.75,  test loss 1.593782, test error 62.65
# Epoch   200, train loss 1.633057, train error 58.47,  test loss 1.452385, test error 55.00
# Epoch   300, train loss 1.607363, train error 56.85,  test loss 1.429278, test error 54.40
# Epoch   400, train loss 1.607674, train error 56.58,  test loss 1.456028, test error 55.22
# Epoch   500, train loss 1.588749, train error 56.08,  test loss 1.439981, test error 54.55
# Epoch   600, train loss 1.580295, train error 55.70,  test loss 1.425729, test error 54.22
# Epoch   700, train loss 1.579783, train error 56.05,  test loss 1.432815, test error 54.62
# Epoch   800, train loss 1.580501, train error 56.05,  test loss 1.447375, test error 55.00
# Epoch   900, train loss 1.578822, train error 55.53,  test loss 1.433394, test error 54.95
# Training model with   8 hidden variables
# Epoch     0, train loss 2.230713, train error 83.12,  test loss 2.213261, test error 83.12
# Epoch   100, train loss 1.633655, train error 57.65,  test loss 1.475438, test error 57.60
# Epoch   200, train loss 1.605432, train error 56.60,  test loss 1.454880, test error 56.50
# Epoch   300, train loss 1.580560, train error 55.85,  test loss 1.452055, test error 56.38
# Epoch   400, train loss 1.567013, train error 55.58,  test loss 1.449139, test error 56.08
# Epoch   500, train loss 1.546345, train error 54.33,  test loss 1.451190, test error 55.53
# Epoch   600, train loss 1.535865, train error 53.62,  test loss 1.465510, test error 55.42
# Epoch   700, train loss 1.524004, train error 53.85,  test loss 1.454858, test error 55.38
# Epoch   800, train loss 1.519230, train error 53.30,  test loss 1.455002, test error 54.72
# Epoch   900, train loss 1.518185, train error 52.97,  test loss 1.464384, test error 55.45
# Training model with  10 hidden variables
# Epoch     0, train loss 2.246794, train error 85.57,  test loss 2.224661, test error 84.88
# Epoch   100, train loss 1.541222, train error 52.70,  test loss 1.392777, test error 52.92
# Epoch   200, train loss 1.472184, train error 49.33,  test loss 1.340470, test error 48.22
# Epoch   300, train loss 1.443464, train error 48.65,  test loss 1.336586, test error 48.62
# Epoch   400, train loss 1.420594, train error 47.05,  test loss 1.327305, test error 48.17
# Epoch   500, train loss 1.410721, train error 47.30,  test loss 1.339480, test error 48.97
# Epoch   600, train loss 1.402829, train error 47.00,  test loss 1.329902, test error 48.42
# Epoch   700, train loss 1.405009, train error 47.17,  test loss 1.338600, test error 48.35
# Epoch   800, train loss 1.401373, train error 47.25,  test loss 1.347538, test error 49.17
# Epoch   900, train loss 1.399679, train error 47.00,  test loss 1.354375, test error 48.65
# Training model with  14 hidden variables
# Epoch     0, train loss 2.281243, train error 87.25,  test loss 2.270524, test error 87.20
# Epoch   100, train loss 1.438338, train error 49.15,  test loss 1.356912, test error 51.75
# Epoch   200, train loss 1.343941, train error 45.15,  test loss 1.327206, test error 49.85
# Epoch   300, train loss 1.306617, train error 43.95,  test loss 1.335518, test error 48.88
# Epoch   400, train loss 1.286116, train error 44.00,  test loss 1.346267, test error 49.15
# Epoch   500, train loss 1.270408, train error 43.72,  test loss 1.366614, test error 48.58
# Epoch   600, train loss 1.261921, train error 42.88,  test loss 1.378248, test error 49.67
# Epoch   700, train loss 1.252929, train error 42.92,  test loss 1.393542, test error 49.05
# Epoch   800, train loss 1.244957, train error 42.22,  test loss 1.411297, test error 48.75
# Epoch   900, train loss 1.245212, train error 42.42,  test loss 1.417934, test error 48.95
# Training model with  18 hidden variables
# Epoch     0, train loss 2.225786, train error 81.32,  test loss 2.211185, test error 81.10
# Epoch   100, train loss 1.370129, train error 47.35,  test loss 1.400998, test error 52.15
# Epoch   200, train loss 1.256181, train error 43.12,  test loss 1.406804, test error 51.83
# Epoch   300, train loss 1.220919, train error 42.20,  test loss 1.446437, test error 52.47
# Epoch   400, train loss 1.194698, train error 41.53,  test loss 1.487975, test error 52.90
# Epoch   500, train loss 1.173944, train error 40.05,  test loss 1.503949, test error 52.97
# Epoch   600, train loss 1.148237, train error 39.22,  test loss 1.528802, test error 53.70
# Epoch   700, train loss 1.136170, train error 38.33,  test loss 1.571058, test error 53.58
# Epoch   800, train loss 1.138615, train error 38.30,  test loss 1.607366, test error 53.70
# Epoch   900, train loss 1.126148, train error 37.92,  test loss 1.645852, test error 55.45
# Training model with  22 hidden variables
# Epoch     0, train loss 2.145994, train error 79.22,  test loss 2.102901, test error 78.25
# Epoch   100, train loss 1.330991, train error 43.92,  test loss 1.394141, test error 53.05
# Epoch   200, train loss 1.203686, train error 40.78,  test loss 1.435438, test error 52.17
# Epoch   300, train loss 1.138897, train error 38.20,  test loss 1.513785, test error 53.40
# Epoch   400, train loss 1.100811, train error 37.05,  test loss 1.571308, test error 54.08
# Epoch   500, train loss 1.085456, train error 36.28,  test loss 1.645187, test error 53.97
# Epoch   600, train loss 1.065948, train error 35.68,  test loss 1.667547, test error 53.35
# Epoch   700, train loss 1.050108, train error 35.20,  test loss 1.704437, test error 53.35
# Epoch   800, train loss 1.039450, train error 35.18,  test loss 1.775483, test error 53.62
# Epoch   900, train loss 1.021033, train error 34.60,  test loss 1.805244, test error 53.78
# Training model with  26 hidden variables
# Epoch     0, train loss 2.162232, train error 80.25,  test loss 2.135068, test error 78.75
# Epoch   100, train loss 1.216175, train error 41.40,  test loss 1.345305, test error 49.25
# Epoch   200, train loss 1.038640, train error 36.10,  test loss 1.450191, test error 50.45
# Epoch   300, train loss 0.955732, train error 33.10,  test loss 1.552346, test error 51.33
# Epoch   400, train loss 0.909661, train error 31.28,  test loss 1.709158, test error 53.40
# Epoch   500, train loss 0.866806, train error 29.68,  test loss 1.813947, test error 53.22
# Epoch   600, train loss 0.857284, train error 30.03,  test loss 1.934495, test error 53.70
# Epoch   700, train loss 0.835303, train error 29.70,  test loss 2.020562, test error 52.88
# Epoch   800, train loss 0.824428, train error 29.07,  test loss 2.121087, test error 53.50
# Epoch   900, train loss 0.819819, train error 28.97,  test loss 2.204691, test error 54.62
# Training model with  30 hidden variables
# Epoch     0, train loss 2.130313, train error 78.03,  test loss 2.099304, test error 79.43
# Epoch   100, train loss 1.132611, train error 38.45,  test loss 1.354529, test error 49.30
# Epoch   200, train loss 0.933609, train error 31.43,  test loss 1.517005, test error 49.70
# Epoch   300, train loss 0.847856, train error 28.88,  test loss 1.730856, test error 52.40
# Epoch   400, train loss 0.776976, train error 25.88,  test loss 1.896108, test error 52.83
# Epoch   500, train loss 0.747636, train error 25.03,  test loss 2.067618, test error 54.35
# Epoch   600, train loss 0.740741, train error 25.07,  test loss 2.215230, test error 54.83
# Epoch   700, train loss 0.694485, train error 24.12,  test loss 2.298357, test error 54.00
# Epoch   800, train loss 0.684490, train error 23.65,  test loss 2.410987, test error 54.50
# Epoch   900, train loss 0.681386, train error 23.50,  test loss 2.514864, test error 54.55
# Training model with  35 hidden variables
# Epoch     0, train loss 2.117833, train error 78.03,  test loss 2.099484, test error 78.32
# Epoch   100, train loss 1.034499, train error 34.07,  test loss 1.414636, test error 51.10
# Epoch   200, train loss 0.787595, train error 25.93,  test loss 1.712203, test error 51.72
# Epoch   300, train loss 0.671218, train error 22.18,  test loss 2.091278, test error 54.08
# Epoch   400, train loss 0.600320, train error 19.90,  test loss 2.469857, test error 56.45
# Epoch   500, train loss 0.557909, train error 18.53,  test loss 2.830384, test error 57.38
# Epoch   600, train loss 0.506462, train error 16.38,  test loss 3.125053, test error 58.08
# Epoch   700, train loss 0.490037, train error 16.32,  test loss 3.448574, test error 57.58
# Epoch   800, train loss 0.468854, train error 15.15,  test loss 3.759220, test error 58.67
# Epoch   900, train loss 0.454175, train error 15.65,  test loss 4.102401, test error 59.30
# Training model with  40 hidden variables
# Epoch     0, train loss 2.084759, train error 77.35,  test loss 2.025332, test error 76.00
# Epoch   100, train loss 0.896548, train error 29.55,  test loss 1.449997, test error 48.97
# Epoch   200, train loss 0.597919, train error 19.05,  test loss 1.945994, test error 51.90
# Epoch   300, train loss 0.476198, train error 15.55,  test loss 2.572979, test error 53.15
# Epoch   400, train loss 0.385274, train error 12.35,  test loss 3.275959, test error 54.42
# Epoch   500, train loss 0.323039, train error 10.70,  test loss 3.955893, test error 55.05
# Epoch   600, train loss 0.310111, train error 10.22,  test loss 4.805585, test error 56.30
# Epoch   700, train loss 0.263701, train error 8.70,  test loss 5.339120, test error 55.25
# Epoch   800, train loss 0.282910, train error 9.97,  test loss 6.102381, test error 55.95
# Epoch   900, train loss 0.262154, train error 8.38,  test loss 6.880461, test error 57.28
# Training model with  45 hidden variables
# Epoch     0, train loss 2.053858, train error 76.97,  test loss 2.004741, test error 76.45
# Epoch   100, train loss 0.824378, train error 26.75,  test loss 1.472909, test error 49.35
# Epoch   200, train loss 0.514404, train error 16.15,  test loss 2.144106, test error 52.22
# Epoch   300, train loss 0.327871, train error 10.28,  test loss 3.135332, test error 53.45
# Epoch   400, train loss 0.226849, train error 7.35,  test loss 4.386704, test error 54.90
# Epoch   500, train loss 0.196284, train error 7.25,  test loss 5.629892, test error 56.47
# Epoch   600, train loss 0.096548, train error 2.78,  test loss 6.845254, test error 56.12
# Epoch   700, train loss 0.012910, train error 0.00,  test loss 7.850615, test error 55.65
# Epoch   800, train loss 0.008406, train error 0.00,  test loss 8.537602, test error 55.88
# Epoch   900, train loss 0.006234, train error 0.00,  test loss 9.049727, test error 55.83
# Training model with  50 hidden variables
# Epoch     0, train loss 2.117662, train error 78.30,  test loss 2.085816, test error 76.70
# Epoch   100, train loss 0.718950, train error 22.93,  test loss 1.557411, test error 49.35
# Epoch   200, train loss 0.356018, train error 10.50,  test loss 2.560191, test error 54.00
# Epoch   300, train loss 0.150316, train error 3.20,  test loss 4.081697, test error 55.75
# Epoch   400, train loss 0.033113, train error 0.00,  test loss 5.767529, test error 55.88
# Epoch   500, train loss 0.014185, train error 0.00,  test loss 6.823558, test error 56.40
# Epoch   600, train loss 0.008747, train error 0.00,  test loss 7.465407, test error 56.22
# Epoch   700, train loss 0.006239, train error 0.00,  test loss 7.967287, test error 56.33
# Epoch   800, train loss 0.004769, train error 0.00,  test loss 8.363077, test error 56.33
# Epoch   900, train loss 0.003843, train error 0.00,  test loss 8.692181, test error 56.47
# Training model with  55 hidden variables
# Epoch     0, train loss 2.064779, train error 76.57,  test loss 2.010341, test error 76.07
# Epoch   100, train loss 0.654156, train error 20.80,  test loss 1.624439, test error 49.67
# Epoch   200, train loss 0.215031, train error 4.55,  test loss 2.923868, test error 53.10
# Epoch   300, train loss 0.048063, train error 0.15,  test loss 4.564533, test error 53.95
# Epoch   400, train loss 0.014786, train error 0.00,  test loss 5.603427, test error 54.10
# Epoch   500, train loss 0.008574, train error 0.00,  test loss 6.230379, test error 54.45
# Epoch   600, train loss 0.005844, train error 0.00,  test loss 6.662727, test error 54.17
# Epoch   700, train loss 0.004408, train error 0.00,  test loss 7.007442, test error 54.28
# Epoch   800, train loss 0.003441, train error 0.00,  test loss 7.293202, test error 54.22
# Epoch   900, train loss 0.002813, train error 0.00,  test loss 7.525176, test error 54.30
# Training model with  60 hidden variables
# Epoch     0, train loss 2.065395, train error 77.28,  test loss 2.009719, test error 77.18
# Epoch   100, train loss 0.517916, train error 14.97,  test loss 1.667732, test error 49.03
# Epoch   200, train loss 0.098964, train error 0.78,  test loss 3.253033, test error 52.78
# Epoch   300, train loss 0.019912, train error 0.00,  test loss 4.588276, test error 53.08
# Epoch   400, train loss 0.009636, train error 0.00,  test loss 5.256668, test error 52.80
# Epoch   500, train loss 0.006015, train error 0.00,  test loss 5.701446, test error 52.95
# Epoch   600, train loss 0.004293, train error 0.00,  test loss 6.024575, test error 52.85
# Epoch   700, train loss 0.003294, train error 0.00,  test loss 6.284722, test error 52.92
# Epoch   800, train loss 0.002636, train error 0.00,  test loss 6.492017, test error 52.85
# Epoch   900, train loss 0.002190, train error 0.00,  test loss 6.676067, test error 53.05
# Training model with  70 hidden variables
# Epoch     0, train loss 2.065876, train error 76.30,  test loss 2.000659, test error 75.12
# Epoch   100, train loss 0.349521, train error 8.60,  test loss 2.023775, test error 52.12
# Epoch   200, train loss 0.030745, train error 0.00,  test loss 3.688647, test error 53.72
# Epoch   300, train loss 0.010468, train error 0.00,  test loss 4.484462, test error 53.83
# Epoch   400, train loss 0.005950, train error 0.00,  test loss 4.931550, test error 54.03
# Epoch   500, train loss 0.004016, train error 0.00,  test loss 5.238559, test error 53.85
# Epoch   600, train loss 0.002986, train error 0.00,  test loss 5.480013, test error 54.00
# Epoch   700, train loss 0.002343, train error 0.00,  test loss 5.674850, test error 53.95
# Epoch   800, train loss 0.001915, train error 0.00,  test loss 5.836898, test error 53.92
# Epoch   900, train loss 0.001609, train error 0.00,  test loss 5.975658, test error 53.97
# Training model with  80 hidden variables
# Epoch     0, train loss 2.011307, train error 76.93,  test loss 1.935000, test error 75.65
# Epoch   100, train loss 0.226439, train error 3.80,  test loss 2.157521, test error 52.45
# Epoch   200, train loss 0.019386, train error 0.00,  test loss 3.511545, test error 52.45
# Epoch   300, train loss 0.007735, train error 0.00,  test loss 4.073067, test error 52.38
# Epoch   400, train loss 0.004600, train error 0.00,  test loss 4.413407, test error 52.55
# Epoch   500, train loss 0.003168, train error 0.00,  test loss 4.651049, test error 52.65
# Epoch   600, train loss 0.002389, train error 0.00,  test loss 4.835284, test error 52.78
# Epoch   700, train loss 0.001898, train error 0.00,  test loss 4.983455, test error 52.78
# Epoch   800, train loss 0.001563, train error 0.00,  test loss 5.112477, test error 52.70
# Epoch   900, train loss 0.001323, train error 0.00,  test loss 5.224162, test error 52.72
# Training model with  90 hidden variables
# Epoch     0, train loss 2.007327, train error 75.55,  test loss 1.945801, test error 74.53
# Epoch   100, train loss 0.144301, train error 1.00,  test loss 2.202461, test error 51.28
# Epoch   200, train loss 0.014897, train error 0.00,  test loss 3.206743, test error 51.55
# Epoch   300, train loss 0.006600, train error 0.00,  test loss 3.630286, test error 51.83
# Epoch   400, train loss 0.004052, train error 0.00,  test loss 3.894659, test error 51.83
# Epoch   500, train loss 0.002840, train error 0.00,  test loss 4.086588, test error 51.83
# Epoch   600, train loss 0.002159, train error 0.00,  test loss 4.234896, test error 51.97
# Epoch   700, train loss 0.001727, train error 0.00,  test loss 4.357633, test error 51.88
# Epoch   800, train loss 0.001429, train error 0.00,  test loss 4.461551, test error 52.05
# Epoch   900, train loss 0.001214, train error 0.00,  test loss 4.552230, test error 52.00
# Training model with 100 hidden variables
# Epoch     0, train loss 1.997573, train error 75.15,  test loss 1.919872, test error 73.57
# Epoch   100, train loss 0.081815, train error 0.10,  test loss 2.318951, test error 52.65
# Epoch   200, train loss 0.011610, train error 0.00,  test loss 3.140791, test error 52.03
# Epoch   300, train loss 0.005441, train error 0.00,  test loss 3.493686, test error 52.10
# Epoch   400, train loss 0.003412, train error 0.00,  test loss 3.718311, test error 51.97
# Epoch   500, train loss 0.002435, train error 0.00,  test loss 3.882356, test error 52.15
# Epoch   600, train loss 0.001867, train error 0.00,  test loss 4.010962, test error 52.20
# Epoch   700, train loss 0.001503, train error 0.00,  test loss 4.116469, test error 52.20
# Epoch   800, train loss 0.001250, train error 0.00,  test loss 4.206283, test error 52.22
# Epoch   900, train loss 0.001065, train error 0.00,  test loss 4.283896, test error 52.20
# Training model with 120 hidden variables
# Epoch     0, train loss 1.993602, train error 74.38,  test loss 1.939721, test error 75.75
# Epoch   100, train loss 0.051513, train error 0.03,  test loss 2.314317, test error 51.75
# Epoch   200, train loss 0.009618, train error 0.00,  test loss 2.974595, test error 52.40
# Epoch   300, train loss 0.004726, train error 0.00,  test loss 3.273171, test error 52.58
# Epoch   400, train loss 0.003027, train error 0.00,  test loss 3.463269, test error 52.25
# Epoch   500, train loss 0.002183, train error 0.00,  test loss 3.606530, test error 52.30
# Epoch   600, train loss 0.001687, train error 0.00,  test loss 3.719135, test error 52.50
# Epoch   700, train loss 0.001364, train error 0.00,  test loss 3.811830, test error 52.42
# Epoch   800, train loss 0.001138, train error 0.00,  test loss 3.891403, test error 52.47
# Epoch   900, train loss 0.000972, train error 0.00,  test loss 3.960937, test error 52.55
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952413, train error 72.18,  test loss 1.869762, test error 71.55
# Epoch   100, train loss 0.036020, train error 0.00,  test loss 2.124455, test error 49.15
# Epoch   200, train loss 0.008082, train error 0.00,  test loss 2.590281, test error 49.50
# Epoch   300, train loss 0.004159, train error 0.00,  test loss 2.813058, test error 49.53
# Epoch   400, train loss 0.002704, train error 0.00,  test loss 2.959924, test error 49.47
# Epoch   500, train loss 0.001967, train error 0.00,  test loss 3.070239, test error 49.62
# Epoch   600, train loss 0.001529, train error 0.00,  test loss 3.156721, test error 49.60
# Epoch   700, train loss 0.001241, train error 0.00,  test loss 3.229240, test error 49.65
# Epoch   800, train loss 0.001040, train error 0.00,  test loss 3.290970, test error 49.58
# Epoch   900, train loss 0.000891, train error 0.00,  test loss 3.345443, test error 49.65
# Training model with 160 hidden variables
# Epoch     0, train loss 1.941667, train error 71.22,  test loss 1.853839, test error 72.05
# Epoch   100, train loss 0.029621, train error 0.00,  test loss 2.088305, test error 48.47
# Epoch   200, train loss 0.007396, train error 0.00,  test loss 2.504902, test error 48.47
# Epoch   300, train loss 0.003877, train error 0.00,  test loss 2.705972, test error 48.38
# Epoch   400, train loss 0.002536, train error 0.00,  test loss 2.841390, test error 48.40
# Epoch   500, train loss 0.001853, train error 0.00,  test loss 2.941313, test error 48.20
# Epoch   600, train loss 0.001444, train error 0.00,  test loss 3.021704, test error 48.22
# Epoch   700, train loss 0.001174, train error 0.00,  test loss 3.088629, test error 48.22
# Epoch   800, train loss 0.000985, train error 0.00,  test loss 3.145210, test error 48.15
# Epoch   900, train loss 0.000844, train error 0.00,  test loss 3.195126, test error 48.10
# Training model with 180 hidden variables
# Epoch     0, train loss 1.935784, train error 71.18,  test loss 1.880987, test error 72.97
# Epoch   100, train loss 0.023894, train error 0.00,  test loss 2.103713, test error 48.30
# Epoch   200, train loss 0.006462, train error 0.00,  test loss 2.454423, test error 48.42
# Epoch   300, train loss 0.003472, train error 0.00,  test loss 2.635238, test error 48.25
# Epoch   400, train loss 0.002306, train error 0.00,  test loss 2.754198, test error 48.50
# Epoch   500, train loss 0.001697, train error 0.00,  test loss 2.845217, test error 48.40
# Epoch   600, train loss 0.001329, train error 0.00,  test loss 2.917029, test error 48.40
# Epoch   700, train loss 0.001085, train error 0.00,  test loss 2.976817, test error 48.35
# Epoch   800, train loss 0.000912, train error 0.00,  test loss 3.028660, test error 48.28
# Epoch   900, train loss 0.000784, train error 0.00,  test loss 3.073433, test error 48.30
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926582, train error 69.72,  test loss 1.861740, test error 71.85
# Epoch   100, train loss 0.021581, train error 0.00,  test loss 1.980376, test error 48.47
# Epoch   200, train loss 0.006130, train error 0.00,  test loss 2.285065, test error 48.25
# Epoch   300, train loss 0.003329, train error 0.00,  test loss 2.441745, test error 48.45
# Epoch   400, train loss 0.002219, train error 0.00,  test loss 2.549319, test error 48.40
# Epoch   500, train loss 0.001640, train error 0.00,  test loss 2.630577, test error 48.53
# Epoch   600, train loss 0.001288, train error 0.00,  test loss 2.694446, test error 48.35
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.748580, test error 48.38
# Epoch   800, train loss 0.000887, train error 0.00,  test loss 2.795291, test error 48.42
# Epoch   900, train loss 0.000763, train error 0.00,  test loss 2.836378, test error 48.33
# Training model with 250 hidden variables
# Epoch     0, train loss 1.903910, train error 68.85,  test loss 1.835039, test error 70.55
# Epoch   100, train loss 0.017571, train error 0.00,  test loss 1.980655, test error 47.60
# Epoch   200, train loss 0.005404, train error 0.00,  test loss 2.254315, test error 47.97
# Epoch   300, train loss 0.003004, train error 0.00,  test loss 2.399615, test error 47.92
# Epoch   400, train loss 0.002021, train error 0.00,  test loss 2.497188, test error 47.92
# Epoch   500, train loss 0.001502, train error 0.00,  test loss 2.571522, test error 47.88
# Epoch   600, train loss 0.001185, train error 0.00,  test loss 2.631650, test error 47.70
# Epoch   700, train loss 0.000973, train error 0.00,  test loss 2.681948, test error 47.70
# Epoch   800, train loss 0.000821, train error 0.00,  test loss 2.724677, test error 47.65
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.763010, test error 47.70
# Training model with 300 hidden variables
# Epoch     0, train loss 1.900858, train error 68.88,  test loss 1.822237, test error 68.78
# Epoch   100, train loss 0.014384, train error 0.00,  test loss 1.832705, test error 47.28
# Epoch   200, train loss 0.004804, train error 0.00,  test loss 2.040480, test error 46.92
# Epoch   300, train loss 0.002722, train error 0.00,  test loss 2.153921, test error 46.92
# Epoch   400, train loss 0.001855, train error 0.00,  test loss 2.231555, test error 46.90
# Epoch   500, train loss 0.001388, train error 0.00,  test loss 2.291481, test error 46.80
# Epoch   600, train loss 0.001100, train error 0.00,  test loss 2.338932, test error 46.92
# Epoch   700, train loss 0.000906, train error 0.00,  test loss 2.379246, test error 47.00
# Epoch   800, train loss 0.000767, train error 0.00,  test loss 2.414091, test error 47.05
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.444697, test error 47.00
# Training model with 400 hidden variables
# Epoch     0, train loss 1.840346, train error 65.57,  test loss 1.795457, test error 70.22
# Epoch   100, train loss 0.011537, train error 0.00,  test loss 1.809175, test error 47.03
# Epoch   200, train loss 0.004148, train error 0.00,  test loss 1.987476, test error 46.70
# Epoch   300, train loss 0.002403, train error 0.00,  test loss 2.087203, test error 46.58
# Epoch   400, train loss 0.001658, train error 0.00,  test loss 2.157477, test error 46.53
# Epoch   500, train loss 0.001250, train error 0.00,  test loss 2.211106, test error 46.50
# Epoch   600, train loss 0.000996, train error 0.00,  test loss 2.254451, test error 46.45
# Epoch   700, train loss 0.000823, train error 0.00,  test loss 2.291168, test error 46.53
# Epoch   800, train loss 0.000699, train error 0.00,  test loss 2.322597, test error 46.47
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.350483, test error 46.53

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
